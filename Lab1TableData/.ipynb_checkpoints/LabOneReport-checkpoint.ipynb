# %% [markdown]
# # Lab1 Report: data visualization for movies
#    Team member:
#    # 1. Business Understanding
#    Our data set is from Kaggle(https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset). There are 28 features and 5043 observations inside. The features range from country, genres to director names, etc, which is quite comprehensive.
#
#    The purpose of this dataset is to determine or predict the eminence of a movie before releasing to cinema. The dataset collect data of 5000+(relatively large amount in sampling) movies from IMDB website. Since the movies come from 66 different countries, span across about 100 years and involve 2399 dinstinct director names, thousands of actors/actresses, it is diverse and representative. Thus, our chosen data is critical and useful to make prediction. Based on the current dataset, our prediction algorithm take a subset of features as an input build a regression tree and output some possible related-data such as IMDB_score or gross which can describe the greatness of a movie. We can select a set of existed data other than our current dataset to test our prediction algorithm. If the error between the actual data and our predicted data are smaller than a critera value (we say, like 5%), then we could consider our prediction algorithm works well.
#
#    # 2 Data Understanding
#
# ## 2.1 Data Description
# There are the 28 features of the dataset but we only focus on 9 of them which might be have more influence about the eminence of movie, here is a list of the nine features and their attributes:
#
#     'country' - nominal - one hot encoding
#
#     'genres' - nominal - one hot encoding
#
#     'director_name' - nominal - one hot encoding
#
#     'gross' - ratio - float
#
#     'budget' - ratio - float
#
#     'imdb_score' - ratio - float
#
#     'num_user_for_reviews' - ratio - float
#
#     'actor_1_facebook_likes' - ratio - float

# %%
import pandas as pd

mv = pd.read_csv('movie_metadata.csv')
mv.describe()
# mv_grouby = mv.groupby(by = ['genres'])
# mv_grouby.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
mv.info()
mv = mv[['country','genres','director_name','gross','budget','imdb_score','num_user_for_reviews','actor_1_facebook_likes']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# plot_keywords                4890 non-null object
# movie_imdb_link              5043 non-null object
# num_user_for_reviews         5022 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# content_rating               4740 non-null object
# budget                       4551 non-null float64
# title_year                   4935 non-null float64
# actor_2_facebook_likes       5030 non-null float64
# imdb_score                   5043 non-null float64
# aspect_ratio                 4714 non-null float64
# movie_facebook_likes         5043 non-null int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
mv.head()
# Out:
#   country                           genres      director_name        gross  \
# 0     USA  Action|Adventure|Fantasy|Sci-Fi      James Cameron  760505847.0
# 1     USA         Action|Adventure|Fantasy     Gore Verbinski  309404152.0
# 2      UK        Action|Adventure|Thriller         Sam Mendes  200074175.0
# 3     USA                  Action|Thriller  Christopher Nolan  448130642.0
# 4     NaN                      Documentary        Doug Walker          NaN
#
#         budget  imdb_score  num_user_for_reviews  actor_1_facebook_likes
# 0  237000000.0         7.9                3054.0                  1000.0
# 1  300000000.0         7.1                1238.0                 40000.0
# 2  245000000.0         6.8                 994.0                 11000.0
# 3  250000000.0         8.5                2701.0                 27000.0
# 4          NaN         7.1                   NaN                   131.0

# %% [markdown]
# ## 2.2 Data Quality
#
# We will clean our dataset before doing data visualization.

# %%
import numpy as np

missmv = pd.isnull(mv)
mv[missmv.any(axis=1)]
# Out:
#       country                                        genres  \
# 4         NaN                                   Documentary
# 55        USA     Adventure|Animation|Comedy|Family|Fantasy
# 84    Belgium               Action|Adventure|Romance|Sci-Fi
# 98      Japan          Action|Adventure|Drama|Horror|Sci-Fi
# 177       USA           Action|Crime|Drama|Mystery|Thriller
# 199        UK                                Action|Fantasy
# 204     Japan          Action|Adventure|Drama|Horror|Sci-Fi
# 206        UK                                       Fantasy
# 242    France               Adventure|Comedy|Family|Fantasy
# 260       USA                        Action|Adventure|Crime
# 279       NaN                                        Comedy
# 367       USA                       Adventure|Drama|History
# 404       USA           Crime|Drama|Horror|Mystery|Thriller
# 422       USA                    Comedy|Drama|Music|Musical
# 430       USA                         Comedy|Fantasy|Horror
# 444       USA                         Comedy|Family|Fantasy
# 459       USA  Action|Adventure|Crime|Drama|Sci-Fi|Thriller
# 477       USA                                 Drama|Romance
# 479       USA                         Comedy|Family|Fantasy
# 489    France                   Drama|Horror|Mystery|Sci-Fi
# 490       USA               Action|Adventure|Drama|Thriller
# 507    Mexico                              Animation|Family
# 537       USA                 Drama|Fantasy|Horror|Thriller
# 543       USA                           Crime|Drama|Mystery
# 559       USA                  Drama|Horror|Sci-Fi|Thriller
# 593       USA      Adventure|Drama|Fantasy|Mystery|Thriller
# 640       USA                 Action|Drama|History|Thriller
# 642       USA                                        Comedy
# 645       USA                                        Comedy
# 676       USA                              Action|Drama|War
# ...       ...                                           ...
# 4994      USA                         Biography|Documentary
# 4995      USA                                         Drama
# 4996      USA                                        Comedy
# 4999      USA                         Drama|Sci-Fi|Thriller
# 5000      USA                                        Horror
# 5001      USA                             Documentary|Music
# 5002      USA                               Horror|Thriller
# 5003      USA                                         Drama
# 5005      USA                                        Comedy
# 5006      USA                                        Horror
# 5007       UK                            Comedy|Crime|Drama
# 5010      USA                                  Comedy|Drama
# 5013      USA                                  Drama|Family
# 5014   Canada                         Action|Crime|Thriller
# 5016      USA                          Crime|Drama|Thriller
# 5017      USA                                Comedy|Romance
# 5018      USA                                         Drama
# 5019      USA                       Horror|Mystery|Thriller
# 5020      USA                         Drama|Horror|Thriller
# 5022    Kenya                                         Drama
# 5024      USA                               Sci-Fi|Thriller
# 5028  Ireland                                        Horror
# 5030      USA                                         Drama
# 5031      USA                        Comedy|Horror|Thriller
# 5032      USA                                   Crime|Drama
# 5036      USA                                   Crime|Drama
# 5038   Canada                                  Comedy|Drama
# 5039      USA                  Crime|Drama|Mystery|Thriller
# 5040      USA                         Drama|Horror|Thriller
# 5041      USA                          Comedy|Drama|Romance
#
#               director_name        gross      budget  imdb_score  \
# 4               Doug Walker          NaN         NaN         7.1
# 55               Peter Sohn  123070338.0         NaN         6.8
# 84             Roland Joffé          NaN         NaN         4.5
# 98             Hideaki Anno          NaN         NaN         8.2
# 177                     NaN          NaN   1500000.0         7.5
# 199              Matt Birch          NaN         NaN         7.5
# 204            Hideaki Anno          NaN         NaN         8.2
# 206              Matt Birch          NaN         NaN         6.4
# 242      Frédéric Forestier          NaN  78000000.0         5.1
# 260                     NaN          NaN         NaN         7.6
# 279     Christopher Barnard          NaN         NaN         7.2
# 367       Timur Bekmambetov          NaN         NaN         6.1
# 404                     NaN          NaN         NaN         8.6
# 422               Bob Fosse          NaN         NaN         7.8
# 430        George A. Romero          NaN   8000000.0         6.9
# 444             Gary Winick   82506325.0         NaN         6.4
# 459                     NaN          NaN         NaN         8.8
# 477            Henry Jaglom     821997.0         NaN         7.0
# 479                     NaN          NaN         NaN         7.6
# 489   Lucile Hadzihalilovic          NaN         NaN         6.4
# 490            Lee Tamahori   27779888.0         NaN         6.9
# 507        Andrés Couturier          NaN   8000000.0         4.4
# 537                     NaN          NaN         NaN         7.5
# 543                     NaN          NaN         NaN         8.3
# 559            David Pastor      90820.0         NaN         6.0
# 593                     NaN          NaN         NaN         7.5
# 640         Craig Gillespie   27550735.0         NaN         6.8
# 642               Jay Roach   72980108.0         NaN         5.9
# 645                     NaN          NaN         NaN         7.4
# 676             John Milius          NaN  16900000.0         6.4
# ...                     ...          ...         ...         ...
# 4994         Patrick Meaney          NaN     50000.0         7.4
# 4995          Chad Hartigan          NaN     42000.0         6.6
# 4996        Malcolm Goodwin          NaN     45000.0         5.5
# 4999            Kirk Loudon          NaN     75000.0         5.0
# 5000           Travis Legge          NaN     40000.0         3.2
# 5001        Martin Scorsese     321952.0         NaN         8.2
# 5002     Collin Joseph Neal          NaN     50000.0         3.7
# 5003      Bradley Rust Gray      24705.0         NaN         6.3
# 5005        Andrew Bujalski          NaN         NaN         6.9
# 5006            Damir Catic          NaN     60000.0         5.4
# 5007           Ben Wheatley       9609.0         NaN         6.5
# 5010        Andrew Bujalski          NaN         NaN         6.4
# 5013             Eric Eason          NaN     24000.0         7.0
# 5014               Uwe Boll          NaN         NaN         6.3
# 5016        Joseph Mazzella          NaN     25000.0         4.8
# 5017           Travis Legge          NaN     22000.0         3.3
# 5018          Alex Kendrick          NaN     20000.0         6.9
# 5019          Marcus Nispel          NaN         NaN         4.6
# 5020        Brandon Landers          NaN     17350.0         3.0
# 5022             Jim Chuchu          NaN     15000.0         7.4
# 5024            Jason Trost          NaN     20000.0         4.0
# 5028          Ivan Kavanagh          NaN     10000.0         6.7
# 5030           Tadeo Garcia          NaN         NaN         6.1
# 5031     Thomas L. Phillips          NaN    200000.0         5.4
# 5032        Ash Baron-Cohen          NaN         NaN         6.4
# 5036        Anthony Vallone          NaN      3250.0         7.8
# 5038            Scott Smith          NaN         NaN         7.7
# 5039                    NaN          NaN         NaN         7.5
# 5040       Benjamin Roberds          NaN      1400.0         6.3
# 5041            Daniel Hsia      10443.0         NaN         6.3
#
#       num_user_for_reviews  actor_1_facebook_likes
# 4                      NaN                   131.0
# 55                   345.0                   275.0
# 84                    15.0                   622.0
# 98                    13.0                   544.0
# 177                   74.0                   982.0
# 199                    2.0                 10000.0
# 204                   13.0                   544.0
# 206                    2.0                 10000.0
# 242                   36.0                   936.0
# 260                   97.0                   669.0
# 279                    NaN                     5.0
# 367                    1.0                 11000.0
# 404                  270.0                   544.0
# 422                  146.0                   813.0
# 430                  211.0                   875.0
# 444                  102.0                 12000.0
# 459                  394.0                   577.0
# 477                   40.0                   898.0
# 479                   71.0                  1000.0
# 489                    3.0                    23.0
# 490                  182.0                 12000.0
# 507                    1.0                   163.0
# 537                   94.0                  1000.0
# 543                   67.0                   374.0
# 559                  119.0                  3000.0
# 593                  110.0                   898.0
# 640                  113.0                   788.0
# 642                  264.0                  7000.0
# 645                   87.0                   995.0
# 676                  383.0                  1000.0
# ...                    ...                     ...
# 4994                   2.0                    26.0
# 4995                   7.0                   695.0
# 4996                   4.0                   948.0
# 4999                   2.0                   883.0
# 5000                   6.0                   307.0
# 5001                 113.0                   725.0
# 5002                   5.0                   252.0
# 5003                  10.0                   962.0
# 5005                  23.0                    26.0
# 5006                   2.0                     5.0
# 5007                  22.0                   177.0
# 5010                  61.0                    26.0
# 5013                  21.0                    93.0
# 5014                 129.0                   986.0
# 5016                   2.0                   313.0
# 5017                   3.0                   370.0
# 5018                  49.0                    51.0
# 5019                  33.0                   630.0
# 5020                   8.0                   720.0
# 5022                   1.0                   147.0
# 5024                  35.0                   407.0
# 5028                   1.0                    10.0
# 5030                   3.0                    21.0
# 5031                   8.0                   785.0
# 5032                  14.0                   789.0
# 5036                   1.0                    45.0
# 5038                   6.0                   637.0
# 5039                 359.0                   841.0
# 5040                   3.0                     0.0
# 5041                   9.0                   946.0
#
# [1155 rows x 8 columns]

# %% [markdown]
# Above are 1155 rows which contain NaN in at least one attribute we concerned. Budget and gross seems to be absent more frequently in the dataset. The attribute country and director_name occassionaly lack their value. Other attributes are very rare to be empty.
#
# The reason budget and gross are more frequently empty may due to production company or organization refuse to provide those data to the data collector. Also, those value may still in counting process at the time the collector gathering them, so that those data remain empty. And director_name is empty at row 5039 may because the movie does not provide details to public. Row 4 lacks of country value may because its not applicable, this movie may finished by many companies so that it is hard to define a certain region for it. But we do not consider those missing values are mistakes.
#
# The way we want to deal with country and budget is imputation. For country, we can impute it by choosing the mode based on the subgroup of same director since director usually direct in the country where he has most resource; for genres, we can impute it by filling the mode of subgroup of same director as well since people usually have a preference to the genres; for budget, we can impute the value by analyzing the mean of genres. We will eliminate director name missing values because there is no way for us to make an analogy about who is the director. Also, for either missing gross or imdb_score, which is possible to be the label, we choose to elminate those observations. As for actor_1_facebook_likes, it is hard to impute by subgroup and it is meaningless to impute by the mean, median, or mode. Thus, we also delete the observation with missing actor_1_facebook_likes.

# %%
# we first eliminate some missing data like director_name and then do the imputation.
def elminate_missing(df,feature):
    missdf = pd.isnull(df[feature])
    for idx in missdf.index:
        if missdf[idx] == True:
            df = df.drop(idx)
    return df
def impute_missing(df,feature,subgroup_feature):
    missdf = pd.isnull(df[feature])
    for idx in missdf.index:
        if missdf[idx] == True:
            sub = df[subgroup_feature][idx]
            subgp = df[df[subgroup_feature]==sub]
#             print(subgp)
            if subgp is not None:    
                df = df.fillna(subgp[feature].value_counts().index[0])
            else:
                df = deal_missing(df,feature)
    return df       
mv = elminate_missing(mv,'director_name')
mv = elminate_missing(mv,'gross')
mv = elminate_missing(mv,'imdb_score')
mv = elminate_missing(mv,'actor_1_facebook_likes')
mv = impute_missing(mv,'country','director_name')
mv = impute_missing(mv,'genres','director_name')
mv = impute_missing(mv,'budget','genres')
mv
# Out:
#           country                                             genres  \
# 0             USA                    Action|Adventure|Fantasy|Sci-Fi
# 1             USA                           Action|Adventure|Fantasy
# 2              UK                          Action|Adventure|Thriller
# 3             USA                                    Action|Thriller
# 5             USA                            Action|Adventure|Sci-Fi
# 6             USA                           Action|Adventure|Romance
# 7             USA  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8             USA                            Action|Adventure|Sci-Fi
# 9              UK                   Adventure|Family|Fantasy|Mystery
# 10            USA                            Action|Adventure|Sci-Fi
# 11            USA                            Action|Adventure|Sci-Fi
# 12             UK                                   Action|Adventure
# 13            USA                           Action|Adventure|Fantasy
# 14            USA                           Action|Adventure|Western
# 15            USA                    Action|Adventure|Fantasy|Sci-Fi
# 16            USA                    Action|Adventure|Family|Fantasy
# 17            USA                            Action|Adventure|Sci-Fi
# 18            USA                           Action|Adventure|Fantasy
# 19            USA      Action|Adventure|Comedy|Family|Fantasy|Sci-Fi
# 20    New Zealand                                  Adventure|Fantasy
# 21            USA                           Action|Adventure|Fantasy
# 22            USA                     Action|Adventure|Drama|History
# 23            USA                                  Adventure|Fantasy
# 24            USA                           Adventure|Family|Fantasy
# 25    New Zealand                     Action|Adventure|Drama|Romance
# 26            USA                                      Drama|Romance
# 27            USA                            Action|Adventure|Sci-Fi
# 28            USA                   Action|Adventure|Sci-Fi|Thriller
# 29            USA                   Action|Adventure|Sci-Fi|Thriller
# 30             UK                          Action|Adventure|Thriller
# ...           ...                                                ...
# 4974          USA                                     Comedy|Romance
# 4975          USA                           Biography|Comedy|Romance
# 4977          USA                           Comedy|Documentary|Drama
# 4978          USA                                             Comedy
# 4979          USA                                       Comedy|Drama
# 4984          USA                               Comedy|Drama|Romance
# 4987          USA                               Comedy|Drama|Romance
# 4997          USA                                              Drama
# 4998          USA                                     Comedy|Romance
# 5001          USA                                  Documentary|Music
# 5003          USA                                              Drama
# 5004          USA                                            Western
# 5007           UK                                 Comedy|Crime|Drama
# 5008          USA                                             Comedy
# 5009          USA                                      Drama|Fantasy
# 5011       Canada                                       Comedy|Drama
# 5012          USA                        Action|Crime|Drama|Thriller
# 5015          USA                                       Comedy|Drama
# 5021          USA                               Comedy|Drama|Romance
# 5023          USA                                            Romance
# 5025          USA                                Comedy|Crime|Horror
# 5026       France                                Drama|Music|Romance
# 5027         Iran                                              Drama
# 5029        Japan                      Crime|Horror|Mystery|Thriller
# 5033          USA                              Drama|Sci-Fi|Thriller
# 5034  Philippines                                           Thriller
# 5035          USA                Action|Crime|Drama|Romance|Thriller
# 5037          USA                                       Comedy|Drama
# 5041          USA                               Comedy|Drama|Romance
# 5042          USA                                        Documentary
#
#            director_name        gross       budget  imdb_score  \
# 0          James Cameron  760505847.0  237000000.0         7.9
# 1         Gore Verbinski  309404152.0  300000000.0         7.1
# 2             Sam Mendes  200074175.0  245000000.0         6.8
# 3      Christopher Nolan  448130642.0  250000000.0         8.5
# 5         Andrew Stanton   73058679.0  263700000.0         6.6
# 6              Sam Raimi  336530303.0  258000000.0         6.2
# 7           Nathan Greno  200807262.0  260000000.0         7.8
# 8            Joss Whedon  458991599.0  250000000.0         7.5
# 9            David Yates  301956980.0  250000000.0         7.5
# 10           Zack Snyder  330249062.0  250000000.0         6.9
# 11          Bryan Singer  200069408.0  209000000.0         6.1
# 12          Marc Forster  168368427.0  200000000.0         6.7
# 13        Gore Verbinski  423032628.0  225000000.0         7.3
# 14        Gore Verbinski   89289910.0  215000000.0         6.5
# 15           Zack Snyder  291021565.0  225000000.0         7.2
# 16        Andrew Adamson  141614023.0  225000000.0         6.6
# 17           Joss Whedon  623279547.0  220000000.0         8.1
# 18          Rob Marshall  241063875.0  250000000.0         6.7
# 19      Barry Sonnenfeld  179020854.0  225000000.0         6.8
# 20         Peter Jackson  255108370.0  250000000.0         7.5
# 21             Marc Webb  262030663.0  230000000.0         7.0
# 22          Ridley Scott  105219735.0  200000000.0         6.7
# 23         Peter Jackson  258355354.0  225000000.0         7.9
# 24           Chris Weitz   70083519.0  180000000.0         6.1
# 25         Peter Jackson  218051260.0  207000000.0         7.2
# 26         James Cameron  658672302.0  200000000.0         7.7
# 27         Anthony Russo  407197282.0  250000000.0         8.2
# 28            Peter Berg   65173160.0  209000000.0         5.9
# 29       Colin Trevorrow  652177271.0  150000000.0         7.0
# 30            Sam Mendes  304360277.0  200000000.0         7.8
# ...                  ...          ...          ...         ...
# 4974         Julie Davis      33598.0   60000000.0         5.4
# 4975     Myles Berkowitz     536767.0      60000.0         5.3
# 4977     Morgan Spurlock   11529368.0      65000.0         7.3
# 4978       Brandon Trost      40557.0      60000.0         5.6
# 4979        Joe Swanberg      30084.0      70000.0         5.6
# 4984        Edward Burns   10246600.0      25000.0         6.6
# 4987         Lena Dunham     389804.0      65000.0         6.3
# 4997  David Gordon Green     241816.0      42000.0         7.5
# 4998        Kevin Jordan     277233.0      40000.0         7.6
# 5001     Martin Scorsese     321952.0   60000000.0         8.2
# 5003   Bradley Rust Gray      24705.0   60000000.0         6.3
# 5004          Mike Bruce     243768.0      30000.0         4.1
# 5007        Ben Wheatley       9609.0   60000000.0         6.5
# 5008         Kevin Smith    3151130.0     230000.0         7.8
# 5009       James Bidgood       8231.0      27000.0         6.7
# 5011         Neil LaBute    2856622.0      25000.0         7.3
# 5012          David Ayer   10499968.0   35000000.0         5.7
# 5015   Richard Linklater    1227508.0      23000.0         7.1
# 5021         Jay Duplass     192467.0      15000.0         6.6
# 5023          Daryl Wein      76382.0      15000.0         6.2
# 5025         John Waters     180483.0      10000.0         6.1
# 5026     Olivier Assayas     136007.0       4500.0         6.9
# 5027        Jafar Panahi     673780.0      10000.0         7.5
# 5029    Kiyoshi Kurosawa      94596.0    1000000.0         7.4
# 5033       Shane Carruth     424760.0       7000.0         7.0
# 5034    Neill Dela Llana      70071.0       7000.0         6.3
# 5035    Robert Rodriguez    2040920.0       7000.0         6.9
# 5037        Edward Burns       4584.0       9000.0         6.4
# 5041         Daniel Hsia      10443.0   60000000.0         6.3
# 5042            Jon Gunn      85222.0       1100.0         6.6
#
#       num_user_for_reviews  actor_1_facebook_likes
# 0                   3054.0                  1000.0
# 1                   1238.0                 40000.0
# 2                    994.0                 11000.0
# 3                   2701.0                 27000.0
# 5                    738.0                   640.0
# 6                   1902.0                 24000.0
# 7                    387.0                   799.0
# 8                   1117.0                 26000.0
# 9                    973.0                 25000.0
# 10                  3018.0                 15000.0
# 11                  2367.0                 18000.0
# 12                  1243.0                   451.0
# 13                  1832.0                 40000.0
# 14                   711.0                 40000.0
# 15                  2536.0                 15000.0
# 16                   438.0                 22000.0
# 17                  1722.0                 26000.0
# 18                   484.0                 40000.0
# 19                   341.0                 10000.0
# 20                   802.0                  5000.0
# 21                  1225.0                 15000.0
# 22                   546.0                   891.0
# 23                   951.0                  5000.0
# 24                   666.0                 16000.0
# 25                  2618.0                  6000.0
# 26                  2528.0                 29000.0
# 27                  1022.0                 21000.0
# 28                   751.0                 14000.0
# 29                  1290.0                  3000.0
# 30                  1498.0                   883.0
# ...                    ...                     ...
# 4974                  15.0                   238.0
# 4975                  83.0                  1000.0
# 4977                 404.0                     0.0
# 4978                  22.0                   968.0
# 4979                  23.0                 10000.0
# 4984                  36.0                   138.0
# 4987                  35.0                   969.0
# 4997                  76.0                   552.0
# 4998                  26.0                 20000.0
# 5001                 113.0                   725.0
# 5003                  10.0                   962.0
# 5004                   9.0                    32.0
# 5007                  22.0                   177.0
# 5008                 615.0                   898.0
# 5009                  16.0                     0.0
# 5011                 197.0                   136.0
# 5012                 212.0                  1000.0
# 5015                  80.0                     5.0
# 5021                  71.0                   830.0
# 5023                   8.0                   331.0
# 5025                 183.0                   462.0
# 5026                  39.0                   576.0
# 5027                  26.0                     5.0
# 5029                  50.0                    89.0
# 5033                 371.0                   291.0
# 5034                  35.0                     0.0
# 5035                 130.0                   121.0
# 5037                  14.0                   296.0
# 5041                   9.0                   946.0
# 5042                  84.0                    86.0
#
# [4152 rows x 8 columns]

# %%
mv[mv.duplicated(keep = False)]
# Out:
#           country                                            genres  \
# 6             USA                          Action|Adventure|Romance
# 17            USA                           Action|Adventure|Sci-Fi
# 25    New Zealand                    Action|Adventure|Drama|Romance
# 30             UK                         Action|Adventure|Thriller
# 33            USA                          Adventure|Family|Fantasy
# 38            USA                          Adventure|Family|Fantasy
# 40            USA                           Action|Adventure|Sci-Fi
# 50      Australia                                     Drama|Romance
# 63            USA                    Action|Adventure|Drama|Romance
# 79             UK                    Adventure|Drama|Family|Fantasy
# 100           USA                             Action|Crime|Thriller
# 137           USA                    Action|Adventure|Drama|Romance
# 145           USA                          Adventure|Family|Fantasy
# 150           USA                      Action|Comedy|Fantasy|Sci-Fi
# 159            UK                            Action|Adventure|Drama
# 174           USA                   Adventure|Drama|Fantasy|Romance
# 187           USA                   Adventure|Drama|Fantasy|Romance
# 188           USA  Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi
# 213           USA                          Action|Adventure|Fantasy
# 214           USA                                     Action|Sci-Fi
# 231           USA                      Action|Crime|Sci-Fi|Thriller
# 245           USA                    Action|Adventure|Comedy|Sci-Fi
# 249           USA                           Action|Adventure|Sci-Fi
# 271           USA                           Action|Adventure|Comedy
# 280           USA          Action|Adventure|Romance|Sci-Fi|Thriller
# 286            UK                         Action|Adventure|Thriller
# 287           USA                  Action|Adventure|Sci-Fi|Thriller
# 303           USA                          Adventure|Family|Fantasy
# 305           USA                           Action|Romance|Thriller
# 314           USA                                  Action|Adventure
# ...           ...                                               ...
# 4202          USA                                      Comedy|Sport
# 4282           UK                                             Drama
# 4313          USA                                      Comedy|Crime
# 4350          USA                              Drama|Fantasy|Horror
# 4352          USA                                            Horror
# 4401          USA                            Action|Horror|Thriller
# 4408        China                                      Comedy|Drama
# 4446          USA                     Action|Crime|Mystery|Thriller
# 4466          USA                       Action|Crime|Drama|Thriller
# 4489          USA                             Drama|Sci-Fi|Thriller
# 4493      Germany                      Crime|Drama|Mystery|Thriller
# 4532          USA                                    Fantasy|Horror
# 4557          USA                              Comedy|Drama|Romance
# 4565           UK                                Comedy|Drama|Music
# 4569          USA            Adventure|Comedy|Family|Fantasy|Horror
# 4584          USA                            Drama|Fantasy|Thriller
# 4631           UK                      Crime|Drama|Mystery|Thriller
# 4649          USA                             Action|Drama|Thriller
# 4681          USA             Drama|Fantasy|Horror|Mystery|Thriller
# 4694  New Zealand                    Action|Adventure|Drama|Romance
# 4695    Australia                                            Horror
# 4752          USA  Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi
# 4769          USA                                      Comedy|Drama
# 4778          USA                          Adventure|Family|Fantasy
# 4821          USA                                   Horror|Thriller
# 4842          USA                     Drama|Fantasy|Musical|Romance
# 4905          USA                              Crime|Drama|Thriller
# 4936          USA                                   Horror|Thriller
# 4971          USA                             Crime|Horror|Thriller
# 5012          USA                       Action|Crime|Drama|Thriller
#
#                          director_name        gross       budget  imdb_score  \
# 6                            Sam Raimi  336530303.0  258000000.0         6.2
# 17                         Joss Whedon  623279547.0  220000000.0         8.1
# 25                       Peter Jackson  218051260.0  207000000.0         7.2
# 30                          Sam Mendes  304360277.0  200000000.0         7.8
# 33                          Tim Burton  334185206.0  200000000.0         6.5
# 38                           Sam Raimi  234903076.0  215000000.0         6.4
# 40                     Joseph Kosinski  172051787.0  170000000.0         6.8
# 50                        Baz Luhrmann  144812796.0  105000000.0         7.3
# 63                         David Yates  124051759.0  180000000.0         6.6
# 79                         Jon Favreau  362645141.0  175000000.0         7.8
# 100                          Rob Cohen  144512310.0   38000000.0         6.7
# 137                        David Yates  124051759.0  180000000.0         6.6
# 145                         Joe Wright   34964818.0  150000000.0         5.8
# 150                          Paul Feig  118099659.0  144000000.0         5.5
# 159                       Ridley Scott   65007045.0  140000000.0         6.1
# 174                        Bill Condon  292298923.0  120000000.0         5.5
# 187                        Bill Condon  292298923.0  120000000.0         5.5
# 188                        Tim Johnson  177343675.0  135000000.0         6.7
# 213                    Louis Leterrier  163192114.0  125000000.0         5.8
# 214                     Paul Verhoeven  119412921.0   65000000.0         7.5
# 231                       José Padilha   58607007.0  100000000.0         6.2
# 245                 Jonathan Liebesman  190871240.0  125000000.0         5.9
# 249                         Josh Trank   56114221.0  120000000.0         4.3
# 271                       Frank Coraci   24004159.0  110000000.0         5.8
# 280                        Michael Bay   35799026.0  126000000.0         6.9
# 286                    Martin Campbell  167007184.0  150000000.0         8.0
# 287                         Tim Burton  180011740.0  100000000.0         5.7
# 303                         Joe Wright   34964818.0  150000000.0         5.8
# 305   Florian Henckel von Donnersmarck   67631157.0  100000000.0         6.0
# 314                       Brett Ratner   72660029.0  100000000.0         6.0
# ...                                ...          ...          ...         ...
# 4202           Rawson Marshall Thurber  114324072.0   20000000.0         6.7
# 4282                   Kenneth Branagh    4414535.0   18000000.0         7.8
# 4313                   Bruce McCulloch   13973532.0   25000000.0         5.1
# 4350                   Kimberly Peirce   35266619.0   30000000.0         5.9
# 4352                        Wes Craven   26505000.0    1800000.0         7.5
# 4401                       Zack Snyder   58885635.0   26000000.0         7.4
# 4408                       Yimou Zhang     190666.0   60000000.0         5.7
# 4446             Christopher McQuarrie   80033643.0   60000000.0         7.0
# 4466                     Harold Becker   32940507.0   60000000.0         6.1
# 4489                  Scott Derrickson   79363785.0   80000000.0         5.5
# 4493                     Paul McGuigan   22494487.0   27000000.0         7.8
# 4532                    John Carpenter   21378000.0    1000000.0         6.8
# 4557                     Jason Reitman  143492840.0    7500000.0         7.5
# 4565                    Peter Cattaneo   45857453.0    3500000.0         7.2
# 4569                     Rob Letterman   80021740.0   58000000.0         6.4
# 4584                     Peter Jackson   43982842.0   65000000.0         6.7
# 4631                       Danny Boyle    2319187.0   20000000.0         7.0
# 4649                   Ric Roman Waugh   42919096.0   15000000.0         6.5
# 4681                    David S. Goyer   42638165.0   16000000.0         4.8
# 4694                     Peter Jackson  218051260.0  207000000.0         7.2
# 4695                Jaume Collet-Serra   32048809.0   30000000.0         5.3
# 4752                       Tim Johnson  177343675.0  135000000.0         6.7
# 4769                       Tamra Davis   37188667.0   12000000.0         3.3
# 4778                         Sam Raimi  234903076.0  215000000.0         6.4
# 4821                    John Carpenter   47000000.0     300000.0         7.9
# 4842                      Julie Taymor   24343673.0   45000000.0         7.4
# 4905                 Steven Soderbergh   32154410.0   30000000.0         7.1
# 4936                       Tobe Hooper   30859000.0      83532.0         7.5
# 4971                    Dennis Iliadis   32721635.0   15000000.0         6.6
# 5012                        David Ayer   10499968.0   35000000.0         5.7
#
#       num_user_for_reviews  actor_1_facebook_likes
# 6                   1902.0                 24000.0
# 17                  1722.0                 26000.0
# 25                  2618.0                  6000.0
# 30                  1498.0                   883.0
# 33                   736.0                 40000.0
# 38                   511.0                 44000.0
# 40                   665.0                 12000.0
# 50                   753.0                 29000.0
# 63                   239.0                 11000.0
# 79                   398.0                 19000.0
# 100                  988.0                 23000.0
# 137                  239.0                 11000.0
# 145                  186.0                 20000.0
# 150                 1211.0                   783.0
# 159                  657.0                 23000.0
# 174                  329.0                 21000.0
# 187                  329.0                 21000.0
# 188                  214.0                 17000.0
# 213                  637.0                 14000.0
# 214                  391.0                   605.0
# 231                  630.0                 10000.0
# 245                  491.0                   833.0
# 249                  695.0                   596.0
# 271                  191.0                  1000.0
# 280                  899.0                 19000.0
# 286                 2301.0                  6000.0
# 287                 1368.0                  1000.0
# 303                  186.0                 20000.0
# 305                  374.0                 40000.0
# 314                  269.0                 12000.0
# ...                    ...                     ...
# 4202                 392.0                   989.0
# 4282                 224.0                   597.0
# 4313                  92.0                   985.0
# 4350                 371.0                 17000.0
# 4352                 668.0                 40000.0
# 4401                1057.0                  3000.0
# 4408                  20.0                     9.0
# 4446                 448.0                 10000.0
# 4466                 127.0                 13000.0
# 4489                 698.0                 18000.0
# 4493                 507.0                 13000.0
# 4532                 335.0                  2000.0
# 4557                 881.0                 24000.0
# 4565                 174.0                  1000.0
# 4569                 154.0                  2000.0
# 4584                 593.0                   873.0
# 4631                 212.0                  3000.0
# 4649                 122.0                 12000.0
# 4681                 230.0                 10000.0
# 4694                2618.0                  6000.0
# 4695                 576.0                   730.0
# 4752                 214.0                 17000.0
# 4769                 578.0                  1000.0
# 4778                 511.0                 44000.0
# 4821                1191.0                  2000.0
# 4842                 524.0                  5000.0
# 4905                 274.0                 17000.0
# 4936                 826.0                   383.0
# 4971                 279.0                   956.0
# 5012                 212.0                  1000.0
#
# [194 rows x 8 columns]

# %% [markdown]
# Above are the duplicated rows in the dataset. We choose the option keep equals to False which means if a row repeat more than onece, we print all the duplicate data including the first time it appears. For example, index 174 and index 187 are two identical rows. Thoese duplicated rows appears due to unintentional mistake made by the data provider.
# Duplicated data are useless for our purpose, because we do not want to analyze the exact movie and its data again. We conclude these data are mistakes and need to be eliminated.

# %%
before_drop = len(mv)
mv = mv.drop_duplicates()
after_drop = len(mv)
if after_drop == before_drop - len(mv[mv.duplicated()]):
    print("drop successful")
# mv

# %% [markdown]
# Here, we drop all the duplicate data and test for its correctness.

# %% [markdown]
# ## Feature Discretization
#
# Let's break up the imdb_score into four ranges whose labels are
#
# 0-4 : bad
#
# 4-7 : median
#
# 7-9 : good
#
# 9-10 : fantastic

# %%
mv['score_range'] = pd.cut(mv.imdb_score,[0,4,7,9,10], 
                           labels = ['bad','median','good','fantastic'])
mv.score_range.describe()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# count       4052
# unique         4
# top       median
# freq        2709
# Name: score_range, dtype: object

# %% [markdown]
# # 3 Data Visualization
#
# ## 3.1 Data Exploration

# %%
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline

# %% [markdown]
# ### 3.1.1 Average Gross by top 10 productive country

# %%
plt.style.use('ggplot')

mv_group_country = mv.groupby(by=['country'])
plot1 = mv[['gross','country']].groupby(['country'])['gross'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(5)
plot1
# gross_ave = mv_group_country.gross.mean() 
# ax = gross_ave.plot(kind='barh')
# plt.title('Average Gross by the top 10 productive country')
# Out:
#     country  count
# 46      USA   3154
# 45       UK    352
# 14   France    120
# 16  Germany     85
# 7    Canada     71

# %% [markdown]
# ### 3.1.2 imdb_score by breaked-down-into-categrical country
